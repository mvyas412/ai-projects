# %%
import pandas as pd
import numpy as np
import os
import gensim
import nltk

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /Users/mayank/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /Users/mayank/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /Users/mayank/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /Users/mayank/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /Users/mayank/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# ...

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %%
for file in os.listdir('./data/'):
    print(file)
# Out:
# story.txt

# %%
# Check current working directory
import os
print("Current working directory:", os.getcwd())

# Use absolute path to the file
file_path = "/Users/mayank/Documents/githubrepo/ai-projects/assignments/0607word2vec/data/story.txt"
f = open(file_path, encoding='utf-8')
content = f.read()
f.close()
print(content[:500])
# Out:
# Current working directory: /Users/mayank/Documents/githubrepo/ai-projects/assignments/0607word2vec
# Once upon a time, there was a king who ruled a large kingdom.
# The king lived in a grand palace with the queen.
# The king and the queen had a son, the prince, and a daughter, the princess.
#
# The prince loved to explore the forest.
# The princess enjoyed reading books in the palace library.
# The king protected the kingdom, and the queen cared for the people.
#
# In the kingdom, there was a small village near a river.
# The villagers worked in farms and grew crops like wheat and rice.
# The farmer woke u

# %%
content
# Out:
# 'Once upon a time, there was a king who ruled a large kingdom. \nThe king lived in a grand palace with the queen. \nThe king and the queen had a son, the prince, and a daughter, the princess.\n\nThe prince loved to explore the forest. \nThe princess enjoyed reading books in the palace library. \nThe king protected the kingdom, and the queen cared for the people.\n\nIn the kingdom, there was a small village near a river. \nThe villagers worked in farms and grew crops like wheat and rice. \nThe farmer woke up early in the morning and worked in the field.\n\nA brave knight served the king. \nThe knight fought enemies and protected the kingdom. \nThe knight rode a strong horse into battle.\n\nIn the forest, there lived a wise old man. \nThe old man knew many secrets about nature and animals. \nThe prince met the old man and learned about courage and wisdom.\n\nA dragon lived deep in the mountains. \nThe dragon guarded a hidden treasure. \nMany soldiers tried to defeat the dragon but fail
# ...

# %%
corpus = content

# %%
corpus
# Out:
# 'Once upon a time, there was a king who ruled a large kingdom. \nThe king lived in a grand palace with the queen. \nThe king and the queen had a son, the prince, and a daughter, the princess.\n\nThe prince loved to explore the forest. \nThe princess enjoyed reading books in the palace library. \nThe king protected the kingdom, and the queen cared for the people.\n\nIn the kingdom, there was a small village near a river. \nThe villagers worked in farms and grew crops like wheat and rice. \nThe farmer woke up early in the morning and worked in the field.\n\nA brave knight served the king. \nThe knight fought enemies and protected the kingdom. \nThe knight rode a strong horse into battle.\n\nIn the forest, there lived a wise old man. \nThe old man knew many secrets about nature and animals. \nThe prince met the old man and learned about courage and wisdom.\n\nA dragon lived deep in the mountains. \nThe dragon guarded a hidden treasure. \nMany soldiers tried to defeat the dragon but fail
# ...

# %%
sent_tokenize(corpus)
# Out:
# ['Once upon a time, there was a king who ruled a large kingdom.',
#  'The king lived in a grand palace with the queen.',
#  'The king and the queen had a son, the prince, and a daughter, the princess.',
#  'The prince loved to explore the forest.',
#  'The princess enjoyed reading books in the palace library.',
#  'The king protected the kingdom, and the queen cared for the people.',
#  'In the kingdom, there was a small village near a river.',
#  'The villagers worked in farms and grew crops like wheat and rice.',
#  'The farmer woke up early in the morning and worked in the field.',
#  'A brave knight served the king.',
#  'The knight fought enemies and protected the kingdom.',
#  'The knight rode a strong horse into battle.',
#  'In the forest, there lived a wise old man.',
#  'The old man knew many secrets about nature and animals.',
#  'The prince met the old man and learned about courage and wisdom.',
#  'A dragon lived deep in the mountains.',
# ...

# %%
raw_sent = sent_tokenize(corpus)

# %%
for i in raw_sent:
  print(simple_preprocess(i))
# Out:
# ['once', 'upon', 'time', 'there', 'was', 'king', 'who', 'ruled', 'large', 'kingdom']
# ['the', 'king', 'lived', 'in', 'grand', 'palace', 'with', 'the', 'queen']
# ['the', 'king', 'and', 'the', 'queen', 'had', 'son', 'the', 'prince', 'and', 'daughter', 'the', 'princess']
# ['the', 'prince', 'loved', 'to', 'explore', 'the', 'forest']
# ['the', 'princess', 'enjoyed', 'reading', 'books', 'in', 'the', 'palace', 'library']
# ['the', 'king', 'protected', 'the', 'kingdom', 'and', 'the', 'queen', 'cared', 'for', 'the', 'people']
# ['in', 'the', 'kingdom', 'there', 'was', 'small', 'village', 'near', 'river']
# ['the', 'villagers', 'worked', 'in', 'farms', 'and', 'grew', 'crops', 'like', 'wheat', 'and', 'rice']
# ['the', 'farmer', 'woke', 'up', 'early', 'in', 'the', 'morning', 'and', 'worked', 'in', 'the', 'field']
# ['brave', 'knight', 'served', 'the', 'king']
# ['the', 'knight', 'fought', 'enemies', 'and', 'protected', 'the', 'kingdom']
# ...

# %%
folder_path = "/Users/mayank/Documents/githubrepo/ai-projects/assignments/0607word2vec/data"
story = []
for filename in os.listdir(folder_path):
  file_path=os.path.join(folder_path,filename)
  with open(file_path,encoding='unicode_escape') as f:
    corpus=f.read()
  raw_sent=sent_tokenize(corpus)
  for sent in raw_sent:
    story.append(simple_preprocess(sent))

# %%
story
# Out:
# [['once',
#   'upon',
#   'time',
#   'there',
#   'was',
#   'king',
#   'who',
#   'ruled',
#   'large',
#   'kingdom'],
#  ['the', 'king', 'lived', 'in', 'grand', 'palace', 'with', 'the', 'queen'],
#  ['the',
#   'king',
#   'and',
#   'the',
#   'queen',
#   'had',
#   'son',
#   'the',
#   'prince',
#   'and',
#   'daughter',
#   'the',
#   'princess'],
#  ['the', 'prince', 'loved', 'to', 'explore', 'the', 'forest'],
#  ['the',
#   'princess',
#   'enjoyed',
#   'reading',
#   'books',
#   'in',
#   'the',
#   'palace',
#   'library'],
#  ['the',
#   'king',
#   'protected',
#   'the',
#   'kingdom',
#   'and',
#   'the',
#   'queen',
#   'cared',
#   'for',
#   'the',
#   'people'],
#  ['in', 'the', 'kingdom', 'there', 'was', 'small', 'village', 'near', 'river'],
#  ['the',
#   'villagers',
#   'worked',
#   'in',
#   'farms',
#   'and',
#   'grew',
#   'crops',
#   'like',
#   'wheat',
#   'and',
#   'rice'],
#  ['the',
#   'farmer',
#   'woke',
#   'up',
#   'early',
# ...

# %%
len(story)
# Out:
# 30

# %%
story[0]
# Out:
# ['once',
#  'upon',
#  'time',
#  'there',
#  'was',
#  'king',
#  'who',
#  'ruled',
#  'large',
#  'kingdom']
